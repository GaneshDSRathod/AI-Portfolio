# %%
a = 20
b = 35
c = 20

# %%
if a !=b :                         #Not equal statements
    print('not equal')
# Out:
# not equal

# %%
if a==b :                             #it is equal to statement here
    print('equal')                    # a is not equal
else :                                # so we used else statement
    print('not equal')
# Out:
# not equal

# %%
if a < b :
    print('a is less then b')
# Out:
# a is less then b

# %%
if b > a :
    print('b is greater than a')
# Out:
# b is greater than a

# %%
if a <= b and a <= c :           #used and operator then both must be true
    print('2 conditions')
# Out:
# 2 conditions

# %%
if b <= a or a==c :             # or operator one must be true
    print('2 conditions with or')
# Out:
# 2 conditions with or

# %%
if not a == b :
    print('not part')
# Out:
# not part

# %%
if a == c : print('equal')  #one liner statement can also in one line
# Out:
# equal

# %%
if a==c :
    print('equal')       #condition satisfied so elif statement not required
elif a!=b :
    print('not equal')
# Out:
# equal

# %%
if a !=c :
    print('equal')
elif a!=b:
    print('not equal')
# Out:
# not equal

# %%
if a!= c:          #elif is used when we have sequential condition
    print('not equal')
elif a==b:
    print('equal')
else :                #else no sequential condition this or that
    print("else")
# Out:
# else

# %%
print("if part") if b > a else print("else part") #oneliner if else
# Out:
# if part

# %%
print("if part") if c > a else print("else part")
# Out:
# else part

# %%
f = False

if a == b :    #in this condition first part must be true to execute another
    print('equal')
    if a < b :
        print('else')
else :
    print(f)
# Out:
# False
