# %%
list1 = [1,2,3,4,5]  #this is list [ ] are lists

# %%
list2 = ['one','two','three']

# %%
list3 = [True, False]

# %%
list4 = [5j , 1+2j]

# %%
print(type(list1))
print(type(list2))
print(type(list3))
print(type(list4))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
list1[0]
# Out:
# 1

# %%
list2[1]
# Out:
# 'two'

# %%
list3[1]
# Out:
# False

# %%
list4[0]
# Out:
# 5j

# %%
list1[-1]
# Out:
# 5

# %%
list[1 : 4]
# Out:
# list[slice(1, 4, None)]

# %%
list[0 : 2]
# Out:
# list[slice(0, 2, None)]

# %%
list1[1 :3]  #stops one step before last index -1
# Out:
# [2, 3]

# %%
list1[:3]  #start from 0 index
# Out:
# [1, 2, 3]

# %%
list1[2:] #starts from 2 index
# Out:
# [3, 4, 5]

# %%
list1[-3:-1] #same till -1 will print
# Out:
# [3, 4]

# %%
list1.append(6) #add at end

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list2.append('six')

# %%
list2
# Out:
# ['one', 'two', 'three', 'six']

# %%
list2[3] = 'four' #it replaced the object numbered at 3 to 'four'

# %%
list2
# Out:
# ['one', 'two', 'three', 'four']

# %%
list1.insert(0,10) #insert method

# %%
list1
# Out:
# [10, 1, 2, 3, 4, 5, 6]

# %%
list5 = [10,20,30,'hello','and','welcome']

# %%
list5
# Out:
# [10, 20, 30, 'hello', 'and', 'welcome']

# %%
list1.extend(list2)  #list1 added with list2 but list 2 remains same

# %%
list1
# Out:
# [10, 1, 2, 3, 4, 5, 6, 'one', 'two', 'three', 'four']

# %%
list2
# Out:
# ['one', 'two', 'three', 'four']

# %%
list5.remove(10) #delete 10 from the variable/list

# %%
list5
# Out:
# [20, 30, 'hello', 'and', 'welcome']

# %%
list1.remove('one')  #removed that specific object

# %%
list1.pop()  # remove last element
# Out:
# 'four'

# %%
list1
# Out:
# [10, 1, 2, 3, 4, 5, 6, 'two', 'three']

# %%
list1.pop(0)  # removed 0 inedex element
# Out:
# 1

# %%
list6 = [10, 1, 2, 3, 4, 5, 6, 'two', 'three']

# %%
del list6  #completely delete the list

# %%
list2.sort()  #sort ascending / alphabetically

# %%
list7 = list5.copy()    #copies the list

# %%
list7
# Out:
# [20, 30, 'hello', 'and', 'welcome']

# %%
list7.clear()  #deletes all the elements from the list
